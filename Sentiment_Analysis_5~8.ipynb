# %% [markdown]
# # 감성분석

# %% [markdown]
# ### 데이터 불러오기

# %%
import pandas as pd


# RSS_total 데이터 불러오기
rss_info = pd.read_csv('./data/RSS_total.csv', encoding='ANSI')

# 5월~8월 데이터 슬라이싱
data = rss_info[15077:]

# Unnamed 열 삭제
data.drop(columns=data.columns[data.columns.str.startswith('Unnamed')], inplace=True)

# 인덱스 0부터 시작하도록 리셋
data.reset_index(drop=True, inplace=True)

# 확인
data.head()
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_5248\2370608528.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=data.columns[data.columns.str.startswith('Unnamed')], inplace=True)
#      rgs_dt tck_iem_cd                                            til_ifo  \
# 0  20230501       CERT  Certara, Inc. (CERT) Earnings Expected to Grow...
# 1  20230501        OCN  Sixth Street (TSLX) Earnings Expected to Grow:...
# 2  20230501       CERT  DraftKings (DKNG) to Report Q1 Earnings: What'...
# 3  20230501       TMCI  Truist Securities Initiates Coverage of Treace...
# 4  20230501        NEO  Zacks.com featured highlights Portillo's, NeoG...
#
#        ctgy_cfc_ifo mdi_ifo  \
# 0  Stocks,Investing   Zacks
# 1  Stocks,Investing   Zacks
# 2  Stocks,Investing   Zacks
# ...

# %% [markdown]
# ### 감성분석

# %%
from textblob import TextBlob


# "news_smy_ifo" 열의 감성분석 수행
sentiments = []
for text in data['news_smy_ifo']:
    analysis = TextBlob(text)
    sentiment = analysis.sentiment.polarity
    sentiments.append(sentiment)
    

# 감성분석 결과를 새로운 열로 추가
data['sentiment'] = sentiments


# 결과 출력
data
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_5248\2943648667.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sentiment'] = sentiments
#           rgs_dt tck_iem_cd  \
# 0       20230501       CERT
# 1       20230501        OCN
# 2       20230501       CERT
# 3       20230501       TMCI
# 4       20230501        NEO
# ...          ...        ...
# 131832  20230831         UA
# 131833  20230831     Latest
# 131834  20230831     Latest
# 131835  20230831        ESE
# 131836  20230831       VEEV
#
#                                                   til_ifo  \
# 0       Certara, Inc. (CERT) Earnings Expected to Grow...
# 1       Sixth Street (TSLX) Earnings Expected to Grow:...
# ...

# %%
# 파일로 저장

data.to_csv('./data/Summary_Sentiment.csv', encoding='ANSI', index=False)

# %%
# 확인

pd.read_csv('./data/Summary_Sentiment.csv', encoding='ANSI')
# Out:
#           rgs_dt tck_iem_cd  \
# 0       20230501       CERT
# 1       20230501        OCN
# 2       20230501       CERT
# 3       20230501       TMCI
# 4       20230501        NEO
# ...          ...        ...
# 131832  20230831         UA
# 131833  20230831     Latest
# 131834  20230831     Latest
# 131835  20230831        ESE
# 131836  20230831       VEEV
#
#                                                   til_ifo  \
# 0       Certara, Inc. (CERT) Earnings Expected to Grow...
# 1       Sixth Street (TSLX) Earnings Expected to Grow:...
# 2       DraftKings (DKNG) to Report Q1 Earnings: What'...
# 3       Truist Securities Initiates Coverage of Treace...
# 4       Zacks.com featured highlights Portillo's, NeoG...
# ...                                                   ...
# 131832         Will Lululemon Stock Trade Higher Post Q2?
# 131833  Bain Capital Specialty Finance (BCSF) Price Ta...
# 131834  Griffon (GFF) Price Target Increased by 13.60%...
# ...
